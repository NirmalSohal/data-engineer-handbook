# %%
dataframe = spark.sql("select * from dataexpert_student.student_table")

create_table = spark.sql("CREATE TABLE IF NOT EXISTS dataexpert_student.company_aggregate (company VARCHAR(32), max_age INTEGER, min_age INTEGER)")
create_table

spark.sql("INSERT INTO dataexpert_student.company_aggregate SELECT company, MAX(age), MIN(age) FROM dataexpert_student.student_table GROUP BY company")

dataframe.collect()

# %%
# %sql

select * from dataexpert_student.company_aggregate
